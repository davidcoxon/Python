# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-c8ec22b3e787> in <module>()
# ----> 1 import cv2
#
# /Applications/anaconda3/lib/python3.6/site-packages/cv2/__init__.py in <module>()
#       2 import os
#       3
# ----> 4 from .cv2 import *
#       5 from .data import *
#       6
#
# ImportError: dlopen(/Applications/anaconda3/lib/python3.6/site-packages/cv2/cv2.cpython-36m-darwin.so, 2): Library not loaded: /System/Library/Frameworks/CoreImage.framework/Versions/A/CoreImage
#   Referenced from: /Applications/anaconda3/lib/python3.6/site-packages/cv2/.dylibs/libavcodec.57.107.100.dylib
#   Reason: image not found
