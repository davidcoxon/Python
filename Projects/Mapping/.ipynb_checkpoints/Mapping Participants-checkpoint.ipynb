# %% [markdown]
# # Mapping Participation
#
# This project is based on actual data analysis that I regularly perform as part of my Head of IT role at BALTIC Centre for Contemporary Art.
#
# ![BALTIC](../Images/baltic.png?raw=true)
#
# Baltic is a free to enter Contemporary Art Gallery on the banks of the River Tyne in Gateshead with charity status. The Gallery has an educational programme to accompany its Arts programme providing a variety of artist lead workshops both within the gallery and within the broader community. Off-site workshops includes pop-up acivities at regional festivals and events as well as activities in local libraries and children's centres.
#
# The residents of the Gateshead area are one of BALTIC key audience and as part of BALTIC's partnership with Gateshead Council, ensuring that Gateshead residence engage with BALTIC's artistic programme is therefore a key priority. In order to ensure that targets are met participants of learning activities either on site and off site are asked to provide postcode details when they attend an event. This Data is then analysed.

# %% [markdown]
# ![Map pin](Images/mappin.png?raw=true)
#
# From landmark locations to participant postcodes, many dataset contain some form of geographical data. Being able to visualise this data is often key to understanding the relationship between the datapoints and mapping provides a great way to do this.
#
# When it comes to maps there are an increasing number of options, from [googlemaps](https://www.google.co.uk/maps) and [openstreet maps](https://www.openstreetmap.org/#map=5/54.910/-3.432) to figurative maps and heatmaps.
#
#
# ## Working with Postcodes
#
# Most of us will will not know the longatude and latitudes of a given location, but we may well know the postcode, for this reason its more common to capture postcodes than any other form of location data.
#
# Postcode data however is not terribly useful in its own right, postcode areas highly irregular, different postcodes are different sizes and postcode sysyem is not layed out in a any form of regular pattern. It is therefore very difficult to get insights into geographical groupings from post code alone.
#
# ## Getting Co-ordinates
#
# Before we can start plotting locations it is therefore necessary to be able to convert postcode into some form of co-ordinate system. There are several co-ordinate systems to choose. For example longatude and latitudes or grid reference.
#
# There are many ways that you can get x and y co-ordinates from postcodes. I used a [freemaptools](https://www.freemaptools.com/convert-uk-postcode-to-lat-lng.htm)
#
# If you wanted you could automate this process by using google's [geocoding api](https://developers.google.com/maps/documentation/geocoding/intro#geocoding) for developers.

# %% [markdown]
# # Visualizing Learning participation on Google Maps
#
# The first stage in analysing learning participation was to visualise where participants live by plotting their geographical data on google maps. In order to plot locations on google maps, postcode data must first the converted to latitude and longitude. In the first instance this was performed as an excel vlookup based on data taken from Data.gov.uk relating to regional parlimentary seats. https://www.freemaptools.com/convert-uk-postcode-to-lat-lng.htm was used to get latitude and longitude details for post codes outside of the region.
#
# The data was loaded to Google maps as 3 separate csv files, each .csv file being imported into its own layer within which can be individually styled and labelled.
#
# ![Google Maps](Images/googlemaps.jpeg?raw=true)
#
# The first of the .csv files contained the location data for the venues at which each of the learning activities took place. The second .csv contained information about participants and activities that took place with the Gallery itself and the final .csv caontained the same information for events that took place at off-site locations. The participant information included the dates times and seasons of the different activities, all of which can be used define the colours, styles and visibility of the markers on the map in order to visualize participation patterns.
#
# The boundaries of the Gatehead Local Authority area were downloaded as a .kml file from https://mapit.mysociety.org/area/2523.html. This .kml was then imported into a layer within google maps which clearly identify participation by residents of the metropolitan borough area on the map.
#
#
# ![GoogleMap 2](Maps/learningparticipation20182.png?raw=true)
#
#
# In addition to providing useful monitoring information about the participation in arts activities within the Map data . The participation map can be used as a planning tool to help develope future offsite learning activities aimed at targeting areas not currently being reach by activities undertaken within the gallery.

# %% [markdown]
# # Mapping Venues with plot with matplotlib
#
# Longitude and Latitude basically just x and Y values. If your datapoints are reasonably close together you can plotted them on a very basic level as a scatter plot with matplotlib, seaborn , Bokeh or any other drawing/plotting library.
#
# The Earth is of course a sphere, and if your datapaoints are further apart or you want to plot them in more accuracy you would need to adjust for this. In terms of initial exploratory data analysis however a scatter plot is a very quick way to get an idea of the geographical distribution of your data points.

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab

# import the data into a dataframe
df=pd.read_csv('Data/baltic_venues.csv', sep=',')
print(df.head())

# create a plot

plt.scatter(df['Longitude'],df['Latitude'], s=50, c='red')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

pylab.savefig('Maps/basicplot.png')
plt.show()
# Out:
#                        Venue  postcode  Latitude  Longitude
# 0                     Baltic   NE8 3BA  54.96921   -1.59828
# 1            Birtley Library   DH3 1LE  54.89683   -1.57714
# 2   Blaydon Childrens Centre  NE21 5BT  54.96467   -1.71207
# 3           Chopwell Library  NE17 7HZ  54.91862   -1.81641
# 4  Chowdene Childrens Centre   NE9 7TU  54.92094   -1.58901

# %% [markdown]
# # Mapping Venues with Folium
#
# While a scatter plot gives you a very basic idea of the location of the datapoints in relation to each other, if you want to see how that relates to features like transport networks, facilities you really need to plot this on a map.
#
# ![Folium Map](Images/foliummap.png?raw=true)
#
# [Folium](https://github.com/python-visualization/folium) is a library that allows you to plot maps in python. In this example i've created a map with Folium, set the default view and passed the same longitude and latitude values and venue names and as markers to our map.

# %%
# Making a map using the folium module

# import libraries
import folium
import pandas as pd
import pylab

# import the data into a dataframe
df=pd.read_csv('Data/baltic_venues.csv', sep=',')

# set default position and scale
lon, lat = -1.49828,   54.79921
zoom_start = 10

# initiate map
venue_map = folium.Map(
    location=[lat, lon],
    tiles='OpenStreetMap',
    zoom_start=zoom_start,
    control_scale=True)

# create datapoints manually
venues = [
    {'loc': [54.96921, -1.59828], 'label': 'Baltic'},
    {'loc': [54.89683, -1.57714,], 'label': 'Birtley Library'},
    {'loc': [54.96467, -1.71207], 'label': 'Blaydon Childrens Centre'}] 

# create datapoints with loop
allvenues=[]
for i, row in df.iterrows():
    venue={'loc': [row['Latitude'], row['Longitude']], 'label':row['Venue']}
    allvenues.append(venue)

# Add markers to the map
for venue in allvenues:
    marker = folium.Marker(location=venue['loc'], popup=venue['label'])
    marker.add_to(venue_map)

# The last object in the cell always gets shown in the notebook
pylab.savefig('Maps/folium.png')
venue_map.save('Maps/foliumscale.html')
venue_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Participation Numbers for on/offsite Activity
#
# Where we used the .kml file within Google Maps to see the boundary for the Gateshead Local Authority area. We will need a list or dictionary of all of the postcodes considered to be within the Local Authority area in order to establish what percentages of participant are residents of Gateshead statistically or programmatically.
#
# Although there are a large number of online resources for local authority data, we were unable to find a full list of postcodes by Local Authority in a format that could easily be downloaded and imported to python, the majority of data using alternate geographical units.
#
# Some generic data was available with partial postcode information within each Local authority (eg NE40, NE36 etc). It was possible to match the partial references with full postcodes from the parlimentary seat dataset and then further refinw this list by plotting each of the datapoints on google maps and comparing it with the county boundaries removing any unwanted datapoints manually.

# %%
#import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab

# import all postcodes within GLA Area 
postcodefile="Data/Gatesheadpostcodes.csv"
postcodes=pd.read_csv(postcodefile)
# print(postcodes.shape)

# Transfer GLA postcodes into a dictionary
# Initialize an empty dictionary
postcodedict = {}
# Iterate over codes in postcodes column
codes = postcodes["postcode"]
for c in codes:
    # If the c is in postcodedict, add 1
    if c in postcodedict.keys():
        postcodedict[c]=((postcodedict)[c])+1
    # Else add the count to postcodedict, set the value to 1
    else:
        postcodedict[c]=1    

# import onsite participant postcodes
BALTICfile="Data/BALTIC_Learning_Activities_sep17.csv"
b_participants=pd.read_csv(BALTICfile, encoding = "ISO-8859-1", sep=',')

# Analyse oparticipant postcodes
# initiate counts
bgateshead=0
bcount=0
bcodes = b_participants["Postcode"]

# Iterate over codes in postcodes column
for c in bcodes:

    # If the c is in postcodedict, add 1
    if c in postcodedict.keys():
        bgateshead=bgateshead+1
    # Else add the count to visitcount, set the value to 1
    else:
        bcount=bcount+1    

# print results
print("-------------------------------------")
print(str(bgateshead) + " participants of BALTIC onsite learning events came from Gateshead")
print(str(bcount) + " participants of BALTIC onsite learning events came from outside of Gateshead")
print("-------------------------------------")

# import offsite participant postcodes
offsitefile="Data/OffSite_Learning_Activities_sep17.csv"
off_participants=pd.read_csv(offsitefile)

# initiate counts
offgateshead=0
offcount=0
offcodes = off_participants["Postcode"]

# Iterate over codes in postcodes column
for c in offcodes:

    # If the c is in postcodedict, add 1
    if c in postcodedict.keys():
        offgateshead=offgateshead+1
    # Else add the count to visitcount, set the value to 1
    else:
        offcount=offcount+1         
        
print(str(offgateshead) + " participants of BALTIC offsite learning events came from Gateshead")
print(str(offcount) + " participants of BALTIC offsite learning events came from outside of Gateshead")
print("-------------------------------------")

# %% [markdown]
# # Participation by Date
#
# This Graph was one of the last elements added at the 'putting it altogether' stage, by which time i had learnt a lot more about the structure of the final script, i had progressed to using a single file for all of the data and was declaring all of the dictionaries at the beginning - so the code may seem a little out of place in the cell sequence, but i wanted to practice producing the graph in its own cell before merging it to the final stage.

# %%
### import required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab
from matplotlib import cm
# %matplotlib inline

# initialize empty dictionaries
Date_dict={}; Gates_date_dict={}

# import all participant data & replace blank Numbers with default of 1
Activitiesfile="Data/All_Learning_Activities_sep17.csv"
Participants=pd.read_csv(Activitiesfile, encoding = "ISO-8859-1", sep=',')
for column in Participants:
    Participants['Number'] = Participants['Number'].replace(r'\s+', np.nan, regex=True)
    Participants['Number'] = Participants['Number'].fillna(1) 
    
# process time/date data
Participants['Date'] = pd.to_datetime(Participants['Date'], format="%d/%m/%y")

# Put Participant Date data into dictionary
for index, row in Participants.iterrows():    
    if row['Date'] in Date_dict.keys():
        Date_dict[row['Date']]=((Date_dict[row['Date']])+(int(row['Number'])))
    else:
        Date_dict[row['Date']]=(int(row['Number']))   
        
# create a scatter plot of Participation by date
Date_list=(list(sorted(Date_dict.keys())))
Participation_list = [Date_dict[key] for key in sorted(Date_dict.keys(), reverse=False)]
                
plt.scatter(Date_list,Participation_list,alpha=0.7) #s=scale,c=colour
plt.xlabel("Date")
plt.ylabel("Participation")
plt.title('Participation by Date');

# limit the axis to include only what you want to display
# plt.ylim(['00:00:00','24:00:00'])
# plt.yticks(('10:00:00','12:00:00','14:00:00','16:00:00','18:00:00','20:00:00'))
## plt.xlim(['2017-06-17','2017-07-09'])
# plt.xticks(("2017-03-01",'2017-04-01','2017-04-30'))
plt.xticks(rotation='90')
# plt.subplots_adjust(bottom=0.05)

# print("\n Conversions by time and date : \n ")
pylab.savefig('Graphs/Participation.png')   # save the figure to file
pylab.savefig('Graphs/Participation.pdf') # savefig('salesdistribution.pdf')
plt.show()

# %% [markdown]
# # Participation by Activity Type

# %%
# import modules
import pandas as pd
import matplotlib.pyplot as plt
import pylab

# import all participant data
Activitiesfile="Data/All_Learning_Activities_sep17.csv"
Participants=pd.read_csv(Activitiesfile, encoding = "ISO-8859-1", sep=',')

Gates_participants = Participants

# import all postcodes within GLA Area 
postcodefile="Data/Gatesheadpostcodes.csv"
postcodes=pd.read_csv(postcodefile)

# Transfer GLA postcodes into a dictionary
# Initialize an empty dictionary
postcodedict = {}

# Iterate over codes in postcodes column
codes = postcodes["postcode"]
for c in codes:
    # If the c is in postcodedict, add 1
    if c in postcodedict.keys():
        postcodedict[c]=((postcodedict)[c])+1
    # Else add the count to postcodedict, set the value to 1
    else:
        postcodedict[c]=1        


# create dictionary of Categorys
# Initialize an empty dictionary: Categories
Categories = {}
# Extract Session column from DataFrame: CatCol
CatCol= Participants['Session']
# Iterate over categories column in participants
Total_participants=0
for entry in CatCol:
    Total_participants=Total_participants+1
    # If the Cat in Categories add 1 to value
    if entry in Categories.keys():
        Categories[entry]=((Categories[entry])+1)
    # Else add the Cat to Categories, set the value to 1
    else:
        Categories[entry]=1
              
# create dictionary of categorys for participants from gateshead
# Initialize an empty dictionary: Gates_categories
Gates_categories = {}
# Extract Gateshead Participant
Gates_participants=Participants[Participants['Postcode'].isin(postcodedict)]
# Gates_participants=Participants[~Participants['Postcode'].isin(postcodedict)] # not in gatehead
GatesCatCol= Gates_participants['Session']
# Iterate over Type column in ProdData
Gates_total_participants=0
for entry in GatesCatCol:
    Gates_total_participants=Gates_total_participants+1
    # If the Cat in Categories add 1 to value
    if entry in Gates_categories.keys():
        Gates_categories[entry]=((Gates_categories[entry])+1)
    # Else add the Cat to Categories, set the value to 1
    else:
        Gates_categories[entry]=1

# Print the Category info
print("-------------------------------------")
print((str(Total_participants)) + " participants took part in " + (str(len(Categories))) + " different types of activity" )
print((str(Gates_total_participants)) + " of those participants came from within the Gateshead area")
print("-------------------------------------")        
print("\n Workshops included: \n ")
for k,v in sorted(Categories.items()):
    print ((str(v)) + " participants for " + (str(k)))
print("-------------------------------------") 
print("\n Residents of Gateshead represented: \n ")
for k,v in sorted(Gates_categories.items()):
    print ((str(v)) + " of the participants for " + (str(k)))
print("-------------------------------------") 

# Graph the results
Values=(list(Categories.values()))
labels=(list(Categories.keys()))
x = list(range(len(Categories.values())))
plt.bar(x,Values) # barchart
# plt.plot(Values) # line graph
plt.xticks(x, labels,rotation='vertical')
plt.ylabel('Participants')
plt.xlabel('Category')

# Print the results
pylab.savefig('Graphs/Categories.png',bbox_inches = 'tight')   # save the figure to file
pylab.savefig('Graphs/Categories.pdf') # savefig('salesdistribution.pdf')
plt.show()

# %% [markdown]
# # Refining Postcode definition for Gateshead
#
# After initionally running the Participation by activity type script, the number of participant from certain activities reported as being residents of Gateshead seemed unusually low, cross referencing these numbers with the locations on the map confirmed that there was a degree of undercounting. A quick exploratory look at the data using (Gates_participants['Postcode']) showed a degree of partial postcodes like NE6 and some data with spaces after the last digit which may or may not be in gatehead. The following script allowed all of the none Gateshead postcodes to be exported and replotted on google map for further analysis any postcodes in the gateshead boundary could then be added to the Gatespostcodes.csv file to correct the problem and the previous scripts reran to update the summaries with more accurate results.

# %%
# export none gateshead post codes - for upload to google maps to validate
import csv

# print(Gates_participants['Postcode'])
GatesCatCol= Gates_participants['Postcode']
Outfile='Data/output.csv'
GatesCatCol.to_csv(Outfile, sep='\t', encoding='utf-8')

# %% [markdown]
# # Participation by Location

# %%
# import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab

# import all participant data
Activitiesfile="Data/All_Learning_Activities_sep17.csv"
Participants=pd.read_csv(Activitiesfile, encoding = "ISO-8859-1", sep=',')

# import all postcodes within GLA Area 
postcodefile="Data/Gatesheadpostcodes.csv"
postcodes=pd.read_csv(postcodefile)

# Transfer GLA postcodes into a dictionary
# Initialize an empty dictionary
postcodedict = {}

# Iterate over codes in postcodes column
codes = postcodes["postcode"]
for c in codes:
    # If the c is in postcodedict, add 1
    if c in postcodedict.keys():
        postcodedict[c]=((postcodedict)[c])+1
    # Else add the count to postcodedict, set the value to 1
    else:
        postcodedict[c]=1        

# Initialize an empty dictionary: Venues
Venues = {}
# Extract Venue column from DataFrame: VenCol
VenCol= Participants['Venue']
# Iterate over Venue column in participants
Venue_participants=0
for entry in VenCol:
    Venue_participants=Venue_participants+1
    # If the Ven in Venues add 1 to value
    if entry in Venues.keys():
        Venues[entry]=((Venues[entry])+1)
    # Else add the Ven to Venues, set the value to 1
    else:
        Venues[entry]=1       
              
# create dictionary of Venues for participants from gateshead
# Initialize an empty dictionary: Gates_venues
Gates_venues = {}
# Extract Gateshead Participant
Gates_participants=Participants[Participants['Postcode'].isin(postcodedict)]
GatesVenCol= Gates_participants['Venue']
# Iterate over Venue column in participants
Gates_venue_participants=0
for entry in GatesVenCol:
    Gates_venue_participants=Gates_venue_participants+1
    # If the ven in venues add 1 to value
    if entry in Gates_venues.keys():
        Gates_venues[entry]=((Gates_venues[entry])+1)
    # Else add the Ven to Venues, set the value to 1
    else:
        Gates_venues[entry]=1
        
# Analyse venue postcodes

# extract venue postcodes data
Gates_venue=Participants[Participants["Venue Postcode"].isin(postcodedict)]
Gates_venue=(Gates_venue)["Venue Postcode"]

# initiate dict
Gates_venuecodes={}
# Iterate over codes in Gates_venuecodes column
for c in Gates_venue:
        
    # If the c is in venuecodedict, add 1
    if c in Gates_venuecodes.keys():
        Gates_venuecodes[c]=((Gates_venuecodes[c])+1)
    else:
        # If the c is not in Gates_venuecodes dict add it
        Gates_venuecodes[c]=1 

# Print the Venue info
print("-------------------------------------")
print((str(Venue_participants)) + " participants took part in activities at " + (str(len(Venues))) + " venues" )
print((str(Gates_venue_participants)) + " of those participants came from within the Gateshead area") 
print("-------------------------------------") 
print("\n Activities took place at the following venues: \n ")
for k,v in sorted(Venues.items()):
    print ((str(k)) + " had " + (str(v)) + " participants")
print("-------------------------------------") 
print ((str(len(Gateshead_venue_loc.values()))) + " of these venues are within the Gateshead Area")
print("-------------------------------------") 
print("\n Residents of Gateshead took part at the following venues: \n ")
for k,v in sorted(Gates_venues.items()):
    print ((str(k)) + " had " + (str(v)) + " participants")
print("-------------------------------------") 

# Ensure all venues are in both dictionaries
for venue in Venues:
    if venue not in Gates_venues:
        Gates_venues[venue]=0

# Graph the results
#Values=(list(reversed(sorted(Venues.values()))))
Values = [v for k, v in sorted(Venues.items())]
# Gates_values=(list(reversed(sorted(Gates_venues.values()))))
Gates_values = [v for k, v in sorted(Gates_venues.items())]
labels = [k for k, v in sorted(Venues.items())]
x = list(range(len((Venues.values()))))
# plt.bar(x,Values) # barchart
plt.plot(Values) # line graph
plt.plot(Gates_values) # line graph
plt.xticks(x, labels,rotation='vertical')
plt.ylabel('Participants')
plt.xlabel('Venue')

# Print the results
pylab.savefig('Graphs/venues.png',bbox_inches = 'tight')   # save the figure to file
pylab.savefig('Graphs/venues.pdf') # savefig('salesdistribution.pdf')
plt.show()

# %% [markdown]
# # Travel Distance
#
# Because we have the location of the participants and the venues we can very crudely calculate travel distances. You have to do a little maths to compensate for the curvature of the earth and the distance are the direct distance between the 2 points not taking into account the means of travel, obstructions or route choices.

# %%
# import modules
import pandas as pd
from math import sin, cos, sqrt, atan2, radians

# import participant data
Activitiesfile="Data/All_Learning_Activities_sep17.csv"
Participants=pd.read_csv(Activitiesfile, encoding = "ISO-8859-1", sep=',')

# Calculate Individula Travel distance and add to distance column
R = 3956 # Radius of earth use 6373.0 for kilometers or 3956 for miles

for index, row in Participants.iterrows():
    dlon =(radians(float(row["venue long"]))-(radians(float(row["attend Longitude"]))))
    dlat =((radians(float(row["venue lat"])))-(radians(float(row["attend Latitude"]))))
    a = sin(dlat / 2)**2 + cos(row["venue lat"]) * cos(row["attend Latitude"]) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    Participants.set_value(index, "Distance", distance, takeable=False)

# Calculate Average Travel distances

print("-------------------------------------")
print("Distance Travelled")
print("-------------------------------------")
print("The shortest distance travelled to attend an activity was " + (str(min((Participants)["Distance"]))) + " miles")
print("The largest distance travelled to attend an activity was " + (str(max((Participants)["Distance"]))) + " miles")
print("The average (mean) distance travelled to attend an activity was " + (str(float((Participants)["Distance"].mean()))) + " miles")
print("The average (median) distance travelled to attend an activity was " + (str(float((Participants)["Distance"].median()))) + " miles")
print("The average (mode) distance travelled to attend an activity was " + (str(float((Participants)["Distance"].mode()))) + " miles")
print("-------------------------------------")

# %% [markdown]
# # Instances
#
# Up until now we have only look at the number of different venues and the number of different activity types, meaning that we have not taken any notice of the number of times that each venue hosts different events or the number of different venues that the same activity type takes place, we can think of these as instance that activities take place.
#
# Note: I came up with the idea of instances ater i'd started to pull all the other bits of code together, so it uses a tidier and more concise version of the code that i use in the milage sections following this one, but i wanted to experiment in this version of code so i've added a new juypter cell for it.

# %%
# import modules
import pandas as pd
import numpy as np
from math import sin, cos, sqrt, atan2, radians
import matplotlib.pyplot as plt
import pylab

# import all participant data & replace blank Numbers with default of 1
Activitiesfile="Data/All_Learning_Activities_sep17.csv"
Participants=pd.read_csv(Activitiesfile, encoding = "ISO-8859-1", sep=',')
for column in Participants:
    Participants['Number'] = Participants['Number'].replace(r'\s+', np.nan, regex=True)
    Participants['Number'] = Participants['Number'].fillna(1) 
    
#create a dictionary of gateshead LA postcodes   
postcodefile="Data/Gatesheadpostcodes.csv"
postcodes=pd.read_csv(postcodefile)
postcodedict = {}

for c in postcodes["postcode"]:
    if c not in postcodedict.keys():
        postcodedict[c]=1 
    else:
        postcodedict[c]=((postcodedict)[c])+1
        
# initiate empty dictionaries
Instance_dict={}; Gates_instance_dict={}

Venue_dict={}; Gates_venue_dict={}
Season_dict={}; Gates_season_dict={}
Session_dict={}; Gates_session_dict={}
Date_dict={}; Gates_date_dict={}
Session_count_dict={}

# establish counts
Household_count=0; Gates_household_count=0
Participant_count=0; Gates_participant_count=0
Activity_count=0; Gates_activity_count=0;
Venue_activity_count=0;Gates_venue_activity_count=0

# Put Participant data into relevant dictionaries and increment counts
for index, row in Participants.iterrows():
    Household_count=Household_count+1
    Participant_count=Participant_count+(int(row['Number']))
    
    #Venue
    if row['Venue'] in Venue_dict.keys():
        Venue_dict[row['Venue']]=((Venue_dict[row['Venue']])+(int(row['Number'])))
    else:
        Venue_dict[row['Venue']]=(int(row['Number']))
     
    #Season
    if row['Season'] in Season_dict.keys():
        Season_dict[row['Season']]=((Season_dict[row['Season']])+(int(row['Number'])))
    else:
        Season_dict[row['Season']]=(int(row['Number']))
        
    #Activity
    if row['Session'] in Session_dict.keys():
        Session_dict[row['Session']]=((Session_dict[row['Session']])+(int(row['Number'])))
    else:
        Session_dict[row['Session']]=(int(row['Number']))
        Activity_count=Activity_count+1
        
    #Instance
    Instance=row['Venue']+"_"+row['Session']+"_"+row['Date']
    if Instance in Instance_dict.keys():
        Instance_dict[Instance]=(Instance_dict[Instance]+(int(row['Number'])))
        
    else:
        Instance_dict[Instance]=(int(row['Number']))

print(str(len(Session_dict)) + " different events took place at " + str(len(Venue_dict.keys())) + " different venues")
print("There were a total of " + str(len(Instance_dict.keys())) + " sessions \n") 
# print(Instance_dict.keys())

# %% [markdown]
# # Interactice filtering by Season
#
# Sometimes we only want to look at data from a particular time period or season, so unsurprisingly this was one of the areas that the Learning team were most interested in developing. They wanted a simple way to be filter the results themselves. This block of the code concentrates on presenting a list of seasons to choose from then validating the response and building filters based on that imput. I have striped a lot of the other fuctionality out for testing purposes.

# %%
# import modules
import pandas as pd
import numpy as np
from math import sin, cos, sqrt, atan2, radians
import matplotlib.pyplot as plt
from matplotlib import cm
import pylab
# %matplotlib inline

# import all participant data & replace blank Numbers with default of 1
Activitiesfile="Data/All_Learning_Activities_sep17.csv"
Participants=pd.read_csv(Activitiesfile, encoding = "ISO-8859-1", sep=',')
for column in Participants:
    Participants['Number'] = Participants['Number'].replace(r'\s+', np.nan, regex=True)
    Participants['Number'] = Participants['Number'].fillna(1) 

# initiate empty dictionaries
Period_dict={}   # for initial filtering
Venue_dict={}; Gates_venue_dict={}; Gates_venues_dict={}
Session_dict={}; Gates_session_dict={};Session_count_dict={}
Instance_dict={}; Gates_instance_dict={}
Venue_act_dict={}; Gates_venue_act_dict={}
Activity_dict={}; Gates_activity_dict={}
Season_dict={}; Gates_season_dict={}
Date_dict={}; Gates_date_dict={};Colour_date_dict={}

# get and set filtering input 
print("This project contains data from :")  
for index, row in Participants.iterrows():
    if row['Season'] not in Period_dict.keys():
        Period_dict[row['Season']]=1
print(Period_dict.keys())        
default = "all"
Selected_season = input("Please enter Period name:")
Selected_season=str(Selected_season)
if Selected_season in Period_dict.keys():
    Participants = Participants[Participants['Season'] == Selected_season]
    
# process time/date data
Participants['Dateformat'] = pd.to_datetime(Participants['Date'], format="%d/%m/%y")    
    
#create a dictionary of gateshead LA postcodes   
postcodefile="Data/Gatesheadpostcodes.csv"
postcodes=pd.read_csv(postcodefile)
postcodedict = {}

for c in postcodes["postcode"]:
    if c not in postcodedict.keys():
        postcodedict[c]=1 
    else:
        postcodedict[c]=((postcodedict)[c])+1
        
# initiate empty dictionaries
Venue_dict={}; Gates_venue_dict={}; Gates_venues_dict={}
Session_dict={}; Gates_session_dict={};Session_count_dict={}
Instance_dict={}; Gates_instance_dict={}
Venue_act_dict={}; Gates_venue_act_dict={}
Activity_dict={}; Gates_activity_dict={}
Season_dict={}; Gates_season_dict={}
Date_dict={}; Gates_date_dict={};Colour_date_dict={}

# establish counts
Household_count=0; Gates_household_count=0
Participant_count=0; Gates_participant_count=0

# Put Participant data into relevant dictionaries and increment counts
for index, row in Participants.iterrows():
    Household_count=Household_count+1
    Participant_count=Participant_count+(int(row['Number']))
    
    #Venue
    if row['Venue'] in Venue_dict.keys():
        Venue_dict[row['Venue']]=((Venue_dict[row['Venue']])+(int(row['Number'])))
    else:
        Venue_dict[row['Venue']]=(int(row['Number']))
        
    #Session
    if row['Session'] in Session_dict.keys():
        Session_dict[row['Session']]=((Session_dict[row['Session']])+(int(row['Number'])))
    else:
        Session_dict[row['Session']]=(int(row['Number']))  
        
    #Instance
    Instance=row['Venue']+"_"+row['Session']+"_"+row['Date']
    if Instance in Instance_dict.keys():
        Instance_dict[Instance]=Instance_dict[Instance]+(int(row['Number'])) 
        if row['Session'] in Activity_dict.keys():
            Activity_dict[row['Session']]=Activity_dict[row['Session']]+1
        else:
            Activity_dict[row['Session']]=1    
    else:
        Instance_dict[Instance]=(int(row['Number']))  
        if row['Session'] in Session_count_dict.keys():
            Session_count_dict[row['Session']]=Session_count_dict[row['Session']]+1
        else:
            Session_count_dict[row['Session']]=1 
        if row['Venue'] in Venue_act_dict.keys():
            Venue_act_dict[row['Venue']]=Venue_act_dict[row['Venue']]+1
        else:
            Venue_act_dict[row['Venue']]=1
            
    #Season
    if row['Season'] in Season_dict.keys():
        Season_dict[row['Season']]=((Season_dict[row['Season']])+(int(row['Number'])))
    else:
        Season_dict[row['Season']]=(int(row['Number'])) 
        
    #Date
    if row['Dateformat'] in Date_dict.keys():
        Date_dict[row['Dateformat']]=((Date_dict[row['Dateformat']])+(int(row['Number'])))
    else:
        Date_dict[row['Dateformat']]=(int(row['Number']))
        Colour_date_dict[row['Dateformat']]=(str(row['Venue']))
       
# Put Gateshead Participant data into relevant dictionaries and increment counts

for index, row in (Participants[Participants['Postcode'].isin(postcodedict)]).iterrows():
    Gates_household_count=Gates_household_count+1
    Gates_participant_count=Gates_participant_count+(int(row['Number']))
    
    #Venue
    if row['Venue'] in Gates_venue_dict.keys():
        Gates_venue_dict[row['Venue']]=((Gates_venue_dict[row['Venue']])+(int(row['Number'])))
    else:
        Gates_venue_dict[row['Venue']]=(int(row['Number']))
    #Session
    if row['Session'] in Gates_session_dict.keys():
        Gates_session_dict[row['Session']]=((Gates_session_dict[row['Session']])+(int(row['Number'])))
    else:
        Gates_session_dict[row['Session']]=(int(row['Number']))  
        
    #Instance
    Instance=row['Venue']+"_"+row['Session']+"_"+row['Date']
    if Instance in Gates_instance_dict.keys():
        Gates_instance_dict[Instance]=Gates_instance_dict[Instance]+(int(row['Number'])) 
        if row['Venue'] in Gates_venue_act_dict.keys():
            Gates_venue_act_dict[row['Venue']]=Gates_venue_act_dict[row['Venue']]+1
        else:
            Gates_venue_act_dict[row['Venue']]=1
        if row['Session'] in Gates_activity_dict.keys():
            Gates_activity_dict[row['Session']]=Gates_activity_dict[row['Session']]+1
        else:
            Gates_activity_dict[row['Session']]=1            
    else:
        Gates_instance_dict[Instance]=(int(row['Number']))  
        
    #Season
    if row['Season'] in Gates_season_dict.keys():
        Gates_season_dict[row['Season']]=((Gates_season_dict[row['Season']])+(int(row['Number'])))
    else:
        Gates_season_dict[row['Season']]=(int(row['Number']))
    #Date 
    if row['Dateformat'] in Gates_date_dict.keys():
        Gates_date_dict[row['Dateformat']]=((Gates_date_dict[row['Dateformat']])+(int(row['Number'])))
    else:
        Gates_date_dict[row['Dateformat']]=(int(row['Number']))
        Gates_date_dict[row['Dateformat']]=(int(row['Number']))
        
# Put Gateshead venues into a dictionary and increment counts

Gates_venues_dict={}
for index, row in (Participants[Participants['Venue Postcode'].isin(postcodedict)]).iterrows():
    if row['Venue'] not in Gates_venues_dict.keys():
        Gates_venues_dict[row['Venue']]=1
        
# Ensure all venues are in both dictionaries
for Venue in Venue_dict:
    if Venue not in Gates_venue_dict:
        Gates_venue_dict[Venue]=0  
        
# Ensure all session are in both dictionaries
for session in Session_dict:
    if session not in Gates_session_dict:
        Gates_session_dict[session]=0       
        
# Ensure all Activities are in both dictionaries
for activity in Activity_dict:
    if activity not in Gates_activity_dict:
        Gates_activity_dict[activity]=0 
        
# Ensure all Dates are in both dictionaries (set to 1 if doesn't exist for scaling)
for activity in Activity_dict:
    if activity not in Gates_activity_dict:
        Gates_activity_dict[activity]=0        
         
# Display the Summary info 
print("\n-------------------------------------")
print("Participant Infomation:")
print("-------------------------------------\n")
print((str(Participant_count)) + " participants, with " + str(len(np.unique(list(Participants['Postcode'])))) + " unique postcodes, took part in " + str(len(Instance_dict.keys()))+ " activities ")
print((str(Gates_participant_count)) + " of those participants came from within the Gateshead Local Authority Area")
# print("-------------------------------------\n")        
   
# Graph Participation by date
Date_list=(list(sorted(Date_dict.keys())))
Participation_list = [Date_dict[key] for key in sorted(Date_dict.keys(), reverse=False)]
scale_list =[Gates_date_dict[key] for key in sorted(Gates_date_dict.keys(), reverse=False)]
scaler=(400/(max(Gates_date_dict.values())))
for idx, i in enumerate(scale_list):
    scale_list[idx] = float(i) * float(scaler)

# Set Colours for venues   
col=0
Colour_dict={}
Colour_list=("yellow","orange","sienna","tan","red","purple","navy","blue", "cyan", "green","green","violet","grey","black","pink","brown","slate blue")
for idx,v in Colour_date_dict.items():
    if v not in Colour_dict:
        Colour_dict[v]=Colour_list[col]
        col=col+1               
# Colour_dict = {v: k for k, v in Colour_dict.items()}

for k,v in Colour_date_dict.items():
    if v in Colour_dict : Colour_date_dict[k]=Colour_dict[v]
                
Venue_colour_list = [Colour_date_dict[key] for key in sorted(Date_dict.keys(), reverse=False)]

plt.figure(1, figsize=(8, 6))                
plt.scatter(Date_list,Participation_list,alpha=0.4, s=scale_list,c=Venue_colour_list)
plt.xlabel("Date")
plt.ylabel("Participation")
plt.title('Participation by Date');

# limit the axis to include only what you want to display
plt.xlim(['2017-03-15','2017-10-01'])
plt.xticks(rotation='90')

# print("\n Conversions by time and date : \n ")
pylab.savefig('Graphs/Participation.png')   # save the figure to file
pylab.savefig('Graphs/Participation.pdf') # savefig('salesdistribution.pdf')
plt.show()      

# Display the Activity info       
print("\n-------------------------------------")
print("Activity Infomation:")
print("-------------------------------------\n")

print("There were a total of " + str(len(Instance_dict.keys())) + " events")
print("At " + str(len(Venue_dict.keys()))  + " locations including " + str(len(Session_dict))+ " categories of activity\n")
# print(Instance_dict.keys())  

# Graph the Actitity type data
plt.figure(3,figsize=(8, 6))
SValues=(list(Session_dict.values()))
GSValues=(list(Gates_session_dict.values()))
labels=(list(Session_dict.keys()))
x = list(range(len(Session_dict.values())))
plt.bar(x,SValues) # barchart
plt.bar(x,GSValues) # barchart
# plt.plot(SValues) # line graph
plt.xticks(x, labels,rotation='vertical')
plt.ylabel('Participants')
plt.xlabel('Type of Activity')

# Print the Activity
pylab.savefig('Graphs/Activity.png',bbox_inches = 'tight')   # save the figure to file
pylab.savefig('Graphs/Activity.pdf') # savefig('salesdistribution.pdf')
plt.show()  
    
print("\n-------------------------------------")

# %% [markdown]
# # Putting it all together

# %% [markdown]
# The final stage of the participation tracking project is to pull each of the different elements together, in this case we'll copy and paste each of the code blocks into a .py file. In practice that script would then be installed on the users pc allowing them to analyse event participation each time they update the underlying csv file with updated  participation details. In addition to seeing the analsis run on their machine, the summary statistics and graphs are automatically saved to a desktop folder each time the script is ran allowing the data to be easily included in any relevant reports.
