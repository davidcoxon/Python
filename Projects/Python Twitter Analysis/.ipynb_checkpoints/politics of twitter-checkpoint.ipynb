# %%
# Import package
import tweepy
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Store OAuth authentication credentials in relevant variables
access_token = "put access token here"
access_token_secret = "put access_token_secret here"
consumer_key = "put consumer_key here"
consumer_secret = "put consumer_secret here"

# Pass OAuth details to tweepy's OAuth handler
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# initiate list
tweet_list=[]

# st_class.py
class MyStreamListener(tweepy.StreamListener):
     def __init__(self, api=None):
         super(MyStreamListener, self).__init__()
         self.num_tweets = 0
         self.file = open("politicaltweets.txt", "w")
     def on_status(self, status):
         tweet = status._json
         self.file.write(json.dumps(tweet) + '\n')
         tweet_list.append(status)
         self.num_tweets += 1
         if self.num_tweets < 100:
             return True
         else:
             return False
         self.file.close()

# Initialize Stream listener
l = MyStreamListener()

# Create you Stream object with authentication
stream = tweepy.Stream(auth, l)

# Filter Twitter Streams to capture data by the keywords:
stream.filter(track=['conservative','labour','libdem','green','snp'])

# String of path to file: tweets_data_path
tweets_data_path='politicaltweets.txt'

# Initialize empty list to store tweets: tweets_data
tweets_data=[]

# Open connection to file
tweets_file = open(tweets_data_path, "r")

# Read in tweets and store in list: tweets_data
for line in tweets_file:
    tweet=json.loads(line)
    tweets_data.append(tweet);

# Close connection to file
tweets_file.close()

# Print the keys of the first tweet dict
print(tweets_data[0].keys())

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(tweets_data, columns=('text','lang'))

# Print head of DataFrame
print(df.head())

import re

def word_in_text(word, tweet):
    word = word.lower()
    text = tweet.lower()
    match = re.search(word, tweet)

    if match:
        return True
    return False

# Initialize list to store tweet counts
[conservative, labour, libdem, green, snp] = [0, 0, 0, 0, 0]
 
# Iterate through df, counting the number of tweets in which
# each candidate is mentioned
for index, row in df.iterrows():
    conservative += word_in_text('conservative', row['text'])
    labour += word_in_text('labour', row['text'])
    libdem += word_in_text('libdem', row['text'])
    green += word_in_text('green', row['text'])
    snp += word_in_text('snp', row['text'])

# Set seaborn style
sns.set(color_codes=True)

# Create a list of labels:cd
cd = ['conservative', 'labour', 'libdem','green', 'snp']

# Plot histogram
ax = sns.barplot(cd, [conservative, labour, libdem, green, snp])
ax.set(ylabel="count")
plt.show()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'entities', 'extended_entities', 'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms'])
#                                                 text lang
# 0  RT @IcySoleOnline: ASICS Gel Kayano Knit 'AGAV...   en
# 1  And conservative as usual don't give a fuck ab...   en
# 2  #NowPlaying Quamid Green - All Out on https://...   en
# 3  RT @johnprescott: 1. Vote for HOPE (on ballot ...   en
# 4  RT @UKLabour: Ready to vote Labour today? Know...   en

# %%
# Putting it all together

# Import package
import tweepy
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Store OAuth authentication credentials in relevant variables
access_token = "put access token here"
access_token_secret = "put access_token_secret here"
consumer_key = "put consumer_key here"
consumer_secret = "put consumer_secret here"

# Pass OAuth details to tweepy's OAuth handler
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# initiate list
tweet_list=[]

# st_class.py
class MyStreamListener(tweepy.StreamListener):
     def __init__(self, api=None):
         super(MyStreamListener, self).__init__()
         self.num_tweets = 0
         self.file = open("tweets.txt", "w")
     def on_status(self, status):
         tweet = status._json
         self.file.write(json.dumps(tweet) + '\n')
         tweet_list.append(status)
         self.num_tweets += 1
         if self.num_tweets < 100:
             return True
         else:
             return False
         self.file.close()

# Initialize Stream listener
l = MyStreamListener()

# Create you Stream object with authentication
stream = tweepy.Stream(auth, l)

# Filter Twitter Streams to capture data by the keywords:
stream.filter(track=['teresa may','corbyn','sturgeon','farron'])

# String of path to file: tweets_data_path
tweets_data_path='tweets.txt'

# Initialize empty list to store tweets: tweets_data
tweets_data=[]

# Open connection to file
tweets_file = open(tweets_data_path, "r")

# Read in tweets and store in list: tweets_data
for line in tweets_file:
    tweet=json.loads(line)
    tweets_data.append(tweet);

# Close connection to file
tweets_file.close()

# Print the keys of the first tweet dict
print(tweets_data[0].keys())

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(tweets_data, columns=('text','lang'))

# Print head of DataFrame
print(df.head())

import re

def word_in_text(word, tweet):
    word = word.lower()
    text = tweet.lower()
    match = re.search(word, tweet)

    if match:
        return True
    return False

# Initialize list to store tweet counts
[teresamay, corbyn, sturgeon, farron] = [0, 0, 0, 0]

# Iterate through df, counting the number of tweets in which
# each candidate is mentioned
for index, row in df.iterrows():
    teresamay += word_in_text('teressa May', row['text'])
    corbyn += word_in_text('Corbyn', row['text'])
    sturgeon += word_in_text('Sturgeon', row['text'])
    farron += word_in_text('Farron', row['text'])

# Set seaborn style
sns.set(color_codes=True)

# Create a list of labels:cd
cd = ['may', 'corbyn', 'sturgeon', 'farron']

# Plot histogram
ax = sns.barplot(cd, [teresamay, corbyn, sturgeon, farron])
ax.set(ylabel="count")
plt.show()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])
#                                                 text lang
# 0  RT @rickygervais: Whether you admire Lord Suga...   en
# 1  RT @rickygervais: Whether you admire Lord Suga...   en
# 2  RT @LeaveEUOfficial: Election Day: take nothin...   en
# 3  Corbyn wants to run UK like Venezuela . All eq...   en
# 4  @DelFletch11 @stephenfry I can help with this,...   en

# %%
print(df)
print(teresamay)
print(corbyn)
print(farron)
print(sturgeon)
# Out:
#                                                  text lang
# 0   RT @rickygervais: Whether you admire Lord Suga...   en
# 1   RT @rickygervais: Whether you admire Lord Suga...   en
# 2   RT @LeaveEUOfficial: Election Day: take nothin...   en
# 3   Corbyn wants to run UK like Venezuela . All eq...   en
# 4   @DelFletch11 @stephenfry I can help with this,...   en
# 5                             https://t.co/Ul9PYT98MU  und
# 6   Ho letto uno che paragona #Corbyn a Trump. Per...   it
# 7   Jeremy Corbyn, UK Labour leader, and his terro...   en
# 8   RT @Herring1967: There's a good chance that Ma...   en
# 9   RT @theSNP: FM: "If you want MPs elected who a...   en
# 10                          … https://t.co/dOflNoHWaS  und
# 11             Shipping costs https://t.co/dQJMl3DU0k   en
# 12  RT @IanDunt: If historians ever bother to look...   en
# 13  RT @Corbynator2: @jeremycorbyn Jon Snow at Jer...   en
# 14                        😂😂😂 https://t.co/yqOI4GFq9N  und
# ...
